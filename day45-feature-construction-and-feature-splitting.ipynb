# %%
import pandas as pd
import numpy as np

from scipy import datasets
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression

df = pd.read_csv("Datasets/train.csv")[['Age','Pclass','SibSp','Parch','Survived']]

# %%
df.dropna(inplace=True)
df.head()
# Out:
#     Age  Pclass  SibSp  Parch  Survived
# 0  22.0       3      1      0         0
# 1  38.0       1      1      0         1
# 2  26.0       3      0      0         1
# 3  35.0       1      1      0         1
# 4  35.0       3      0      0         0

# %%
X = df.iloc[:,0:4]
y = df.iloc[:,-1]

# %%
np.mean(cross_val_score(LogisticRegression(),X,y,scoring='accuracy',cv=20))
# Out:
# np.float64(0.6933333333333332)

# %%
X['Family_size'] = X['SibSp'] + X['Parch'] + 1
X.head()
# Out:
#     Age  Pclass  SibSp  Parch  Family_size
# 0  22.0       3      1      0            2
# 1  38.0       1      1      0            2
# 2  26.0       3      0      0            1
# 3  35.0       1      1      0            2
# 4  35.0       3      0      0            1

# %%
def myfunc(num):
    if num == 1:
        #alone
        return 0
    elif num >1 and num <=4:
        # small family
        return 1
    else:
        # large family
        return 2

# %%
myfunc(3)
# Out:
# 1

# %%
X['Family_type'] = X['Family_size'].apply(myfunc)
X.head()
# Out:
#     Age  Pclass  SibSp  Parch  Family_size  Family_type
# 0  22.0       3      1      0            2            1
# 1  38.0       1      1      0            2            1
# 2  26.0       3      0      0            1            0
# 3  35.0       1      1      0            2            1
# 4  35.0       3      0      0            1            0

# %%
X.drop(columns=['SibSp','Parch','Family_size'],inplace=True)

# %%
X.head()
# Out:
#     Age  Pclass  Family_type
# 0  22.0       3            1
# 1  38.0       1            1
# 2  26.0       3            0
# 3  35.0       1            1
# 4  35.0       3            0

# %%
np.mean(cross_val_score(LogisticRegression(),X,y,scoring='accuracy',cv=20))
# Out:
# np.float64(0.7003174603174602)

# %%
newdata = pd.read_csv("Datasets/train.csv")

# %%
newdata['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: str

# %%
newdata['Title'] = newdata['Name'].str.split(', ', expand=True)[1].str.split('.', expand=True)[0]

# %%
newdata['Name'].str.split(', ', expand=True)[1].str.split('.', expand=True)[0]
# Out:
# 0        Mr
# 1       Mrs
# 2      Miss
# 3       Mrs
# 4        Mr
#        ...
# 886     Rev
# 887    Miss
# 888    Miss
# 889      Mr
# 890      Mr
# Name: 0, Length: 891, dtype: str

# %%
newdata[['Title','Name']]
# Out:
#     Title                                               Name
# 0      Mr                            Braund, Mr. Owen Harris
# 1     Mrs  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2    Miss                             Heikkinen, Miss. Laina
# 3     Mrs       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4      Mr                           Allen, Mr. William Henry
# ..    ...                                                ...
# 886   Rev                              Montvila, Rev. Juozas
# 887  Miss                       Graham, Miss. Margaret Edith
# 888  Miss           Johnston, Miss. Catherine Helen "Carrie"
# 889    Mr                              Behr, Mr. Karl Howell
# 890    Mr                                Dooley, Mr. Patrick
#
# [891 rows x 2 columns]

# %%
newdata['Title'] = newdata['Title'].astype('object')

# %%
(newdata.groupby('Title').mean()['Survived']).sort_values
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[163], line 1
# ----> 1 (newdata.groupby('Title').mean()['Survived']).sort_values
#
# File c:\Users\sunil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:2285, in GroupBy.mean(self, numeric_only, skipna, engine, engine_kwargs)
#    2277     return self._numba_agg_general(
#    2278         grouped_mean,
#    2279         executor.float_dtype_mapping,
#    (...)   2282         skipna=skipna,
#    2283     )
#    2284 else:
# -> 2285     result = self._cython_agg_general(
#    2286         "mean",
#    2287         alt=lambda x: Series(x, copy=False).mean(
#    2288             numeric_only=numeric_only, skipna=skipna
#    2289         ),
#    2290         numeric_only=numeric_only,
#    2291         skipna=skipna,
#    2292     )
# ...
